# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

#import matplotlib.pyplot as plt

#plt.style.use('ggplot')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
VOCAB_SIZE = vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:10])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# Sample data [5235, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
# test
print( count[ data[1] ])
print( len(data) )
print( len(count) )
# Out:
# ('originated', 572)
# 17005207
# 50000

# %%
#Let's print some more data
print (data[:10])
print (count[:10])

print (list(dictionary.items())[:10])
print (list(reverse_dictionary.items())[:20])

kk = dictionary['lymphoma']
print(kk)
# Out:
# [5235, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('psychoactive', 17980), ('nobility', 5039), ('prohibitive', 31437), ('radically', 10149), ('alphabetically', 27807), ('comprise', 6657), ('pygmies', 35374), ('tolls', 22005), ('fearful', 15644), ('attar', 49339)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine'), (10, 'two'), (11, 'is'), (12, 'as'), (13, 'eight'), (14, 'for'), (15, 's'), (16, 'five'), (17, 'three'), (18, 'was'), (19, 'by')]
# 32509

# %%
print ('data:', [reverse_dictionary[di] for di in data[:20]] )
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch  = np.ndarray(shape=(batch_size),    dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j]     = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'term', 'of', 'originated', 'as']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term']
#     labels: ['term', 'originated', 'of', 'as', 'a', 'as', 'abuse', 'of']

# %%
print (batch)
print (labels)
# Out:
# [  6   6   6   6 195 195 195 195]
# [[ 195]
#  [3084]
#  [   2]
#  [  12]
#  [   6]
#  [  12]
#  [3135]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1   # How many words to consider left and right.
num_skips = 2     # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, 
                               softmax_biases, 
                               embed,
                               train_labels, 
                               num_sampled, 
                               vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, 
                                            valid_dataset)
  similarity = tf.matmul(valid_embeddings, 
                         tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, 
                                              num_skips, 
                                              skip_window)
    feed_dict = {train_dataset : batch_data, 
                 train_labels : batch_labels}
    # run one optimizer step
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8    # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.337493
# Nearest to people: conflicts, stemmed, bayonet, berle, inhale, polymorphism, darussalam, monotremes,
# Nearest to in: fables, wma, mage, ensuring, leftrightarrow, resold, moron, christmas,
# Nearest to b: stimulating, majesty, ulaanbaatar, corot, ken, wf, cthulhu, kanagawa,
# Nearest to if: snake, olav, crawl, tumor, royalist, wormhole, nde, ambush,
# Nearest to at: exclusivity, france, unction, sufi, zhu, lubricated, scrupulously, esophagus,
# Nearest to this: summons, sulphur, gera, liar, midday, mouth, neman, isles,
# Nearest to with: brute, avery, pla, cholesterol, milosevic, hung, serpent, breakdance,
# Nearest to were: trimmed, ladas, bathtub, chico, penguin, degrades, derry, toussaint,
# Nearest to i: malwa, heineken, puppy, tamed, aeacus, heads, luria, cola,
# Nearest to so: anarchist, impinging, obtains, lehman, colts, marble, masterpiece, organisations,
# Nearest to use: amoral, raceway, deirdre, uncommon, avestan, amedeo, sardar, sartre,
# Nearest to a: gordie, supposed, declaring, altercation, stig, janice, shootout, financi,
# Nearest to between: mitanni, jardine, cbd, embodiment, disclose, casualties, stainless, priest,
# Nearest to one: intercultural, relinquished, silverberg, monks, sheedy, melon, flushed, dormitory,
# Nearest to will: farmed, hometown, vandalism, freeware, supervised, alkaloid, deanna, ericales,
# Nearest to four: stain, labouring, suiko, einhard, telecoms, immanuel, staring, trainee,
# Average loss at step 2000: 4.365868
# Average loss at step 4000: 3.866138
# Average loss at step 6000: 3.788717
# Average loss at step 8000: 3.684060
# Average loss at step 10000: 3.618033
# Nearest to people: fridtjof, viridis, totalling, excesses, unsurpassed, instructive, gonorrhea, hermaphroditus,
# Nearest to in: on, of, at, duff, and, after, with, between,
# Nearest to b: stimulating, metalloid, canines, cthulhu, conservatory, wf, frites, apprentice,
# Nearest to if: when, is, royalist, kevin, namespace, snake, therapists, ships,
# Nearest to at: in, zhu, exclusivity, mencius, under, arabian, terrains, during,
# Nearest to this: it, the, which, uninhabited, written, sulphur, its, sector,
# Nearest to with: denison, in, for, between, into, minimum, worldly, frication,
# Nearest to were: are, was, trimmed, had, keane, have, machado, commercials,
# Nearest to i: malwa, luria, they, insertion, tamed, behaves, salk, we,
# Nearest to so: anarchist, lehman, tenn, masterpiece, bottle, impinging, misunderstood, marble,
# Nearest to use: uncommon, archetypes, amoral, caspian, deirdre, guise, amedeo, internationalist,
# Nearest to a: the, vga, duchies, his, khoikhoi, ladislaus, imperfective, khoi,
# Nearest to between: in, broadway, cbd, jardine, with, rockingham, mitanni, expectations,
# Nearest to one: eight, four, two, six, nic, three, contraband, articles,
# Nearest to will: would, can, alkaloid, farmed, cachet, may, ericales, yokoi,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Average loss at step 12000: 3.605996
# Average loss at step 14000: 3.570693
# Average loss at step 16000: 3.407748
# Average loss at step 18000: 3.454353
# Average loss at step 20000: 3.541081
# Nearest to people: fridtjof, totalling, unsurpassed, gonorrhea, pusc, reins, livre, retaliatory,
# Nearest to in: at, on, with, throughout, from, between, and, during,
# Nearest to b: d, neutronic, anac, stimulating, canines, concur, gravis, alleys,
# Nearest to if: when, considering, does, motivating, rdx, namespace, is, debilitating,
# Nearest to at: in, seizures, tk, on, exclusivity, under, from, during,
# Nearest to this: it, which, the, nominating, transhumanism, uninhabited, acetaldehyde, what,
# Nearest to with: between, in, denison, hbp, without, worldly, into, minimum,
# Nearest to were: are, was, had, have, be, faunas, xml, is,
# Nearest to i: ii, luria, malwa, we, distorting, musab, they, you,
# Nearest to so: anarchist, masterpiece, impinging, misunderstood, thereby, gothenburg, lucan, marble,
# Nearest to use: uncommon, baasha, internationalist, caspian, archetypes, amoral, parks, woodwinds,
# Nearest to a: the, khoi, very, any, involved, magnetism, duchies, etna,
# Nearest to between: with, in, broadway, jardine, rockingham, under, directness, titled,
# Nearest to one: two, four, three, seven, five, eight, six, quantifier,
# Nearest to will: can, would, may, should, could, cachet, alkaloid, farmed,
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Average loss at step 22000: 3.503941
# Average loss at step 24000: 3.487422
# Average loss at step 26000: 3.477046
# Average loss at step 28000: 3.475345
# Average loss at step 30000: 3.503921
# Nearest to people: jews, totalling, fridtjof, americans, conservatives, pusc, bubonic, livre,
# Nearest to in: at, during, varanus, on, schaefer, under, between, of,
# Nearest to b: d, anac, neutronic, conservatory, apprentice, alleys, eucharistic, majesty,
# Nearest to if: when, considering, motivating, does, configurations, namespace, did, although,
# Nearest to at: during, in, zhu, under, nephite, mufti, seizures, tk,
# Nearest to this: which, it, nominating, accessibility, what, another, transhumanism, that,
# Nearest to with: between, against, for, without, when, skeptic, denison, minimum,
# Nearest to were: are, was, had, have, been, is, include, xml,
# Nearest to i: ii, we, luria, you, t, musab, they, distorting,
# Nearest to so: anarchist, impinging, lucan, bottle, masterpiece, things, misunderstood, invariably,
# Nearest to use: uncommon, caspian, archetypes, suicidal, amoral, gaul, modern, internationalist,
# Nearest to a: the, no, any, tiberian, encompass, fridtjof, khoi, his,
# Nearest to between: with, in, broadway, jardine, directness, under, titled, unknowns,
# Nearest to one: two, seven, eight, three, five, four, nine, six,
# Nearest to will: can, would, may, could, should, must, to, alkaloid,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Average loss at step 32000: 3.500417
# Average loss at step 34000: 3.490888
# Average loss at step 36000: 3.455213
# Average loss at step 38000: 3.300917
# Average loss at step 40000: 3.428447
# Nearest to people: jews, americans, individuals, fridtjof, totalling, technetium, livre, mathcal,
# Nearest to in: from, of, during, at, for, since, freeform, diagrams,
# Nearest to b: d, c, r, h, cthulhu, ken, ve, eucharistic,
# Nearest to if: when, escapades, motivating, for, considering, namespace, photographic, does,
# Nearest to at: during, in, freikorps, evergreen, botany, zhu, tk, enhancing,
# Nearest to this: which, it, that, another, the, any, acetaldehyde, what,
# Nearest to with: between, skeptic, speedup, bloodless, gunships, hbp, against, without,
# Nearest to were: are, have, was, had, be, been, while, became,
# Nearest to i: we, you, ii, t, they, luria, who, arranger,
# Nearest to so: impinging, anarchist, more, luxembourgish, less, lucan, argue, sometimes,
# Nearest to use: uncommon, woodwinds, way, rethinking, caspian, parks, uncountably, cases,
# Nearest to a: diamagnetism, the, bulgakov, flutter, umar, enables, asymptotically, any,
# Nearest to between: with, jardine, whisper, unknowns, etzel, broadway, over, shoots,
# Nearest to one: seven, four, two, six, eight, three, five, inches,
# Nearest to will: can, would, may, could, must, should, does, cannot,
# Nearest to four: six, five, seven, eight, three, two, nine, one,
# Average loss at step 42000: 3.431397
# Average loss at step 44000: 3.452280
# Average loss at step 46000: 3.452279
# Average loss at step 48000: 3.358161
# Average loss at step 50000: 3.380063
# Nearest to people: jews, livre, helicopters, members, conservatives, attitude, mathcal, technetium,
# Nearest to in: during, throughout, of, within, on, since, from, and,
# Nearest to b: d, r, c, feyerabend, f, bicentennial, ft, aiken,
# Nearest to if: when, after, though, motivating, escapades, where, configurations, does,
# Nearest to at: during, scrupulously, from, tk, on, in, under, enhancing,
# Nearest to this: which, it, nominating, the, vigilant, he, that, delle,
# Nearest to with: between, hbp, naturally, thermodynamic, gunships, when, through, worldly,
# Nearest to were: are, was, have, had, be, been, chlamydia, is,
# Nearest to i: we, ii, you, t, g, chrysostom, they, megawatts,
# Nearest to so: impinging, lia, anarchist, sometimes, chateau, nashe, poverty, vespers,
# Nearest to use: way, uncommon, rethinking, nature, cause, study, strut, instinctively,
# Nearest to a: any, another, diamagnetism, the, tolerance, every, ber, encompass,
# Nearest to between: with, within, among, under, through, directness, in, shoots,
# Nearest to one: two, four, eight, six, seven, three, outs, five,
# Nearest to will: would, can, could, may, must, should, might, shall,
# Nearest to four: five, eight, six, seven, three, nine, two, zero,
# Average loss at step 52000: 3.434001
# Average loss at step 54000: 3.427901
# Average loss at step 56000: 3.438255
# Average loss at step 58000: 3.394438
# Average loss at step 60000: 3.392586
# Nearest to people: jews, americans, individuals, women, members, men, livre, totalling,
# Nearest to in: within, during, throughout, of, including, between, since, on,
# Nearest to b: d, c, f, r, y, lettering, interpolating, kbe,
# Nearest to if: when, where, though, before, motivating, does, after, since,
# Nearest to at: during, conveniently, in, scrupulously, tk, zhu, under, bleaching,
# Nearest to this: which, it, that, there, the, itself, what, however,
# Nearest to with: between, without, among, skeptic, by, when, sdp, reputable,
# Nearest to were: are, was, those, had, have, including, although, carnivores,
# Nearest to i: we, ii, you, chrysostom, g, t, arranger, they,
# Nearest to so: impinging, sometimes, less, argue, lucan, severe, conquistadores, vespers,
# Nearest to use: uncommon, way, rethinking, cases, form, ossie, most, loew,
# Nearest to a: another, the, any, every, downing, tolerance, andhra, unofficially,
# Nearest to between: with, among, in, within, through, etzel, over, unknowns,
# Nearest to one: two, four, eight, seven, five, six, three, nine,
# Nearest to will: would, can, may, could, must, should, shall, might,
# Nearest to four: five, six, eight, three, seven, nine, zero, two,
# Average loss at step 62000: 3.242610
# Average loss at step 64000: 3.256928
# Average loss at step 66000: 3.405889
# Average loss at step 68000: 3.395352
# Average loss at step 70000: 3.360238
# Nearest to people: jews, members, americans, men, women, students, totalling, lethe,
# Nearest to in: within, on, during, for, until, between, throughout, through,
# Nearest to b: d, f, r, y, tetragrammaton, synchronous, biochemical, kbe,
# Nearest to if: when, though, before, where, while, after, although, does,
# Nearest to at: tk, during, conveniently, nephite, on, scrupulously, mufti, near,
# Nearest to this: which, it, the, that, itself, nominating, another, vigilant,
# Nearest to with: between, skeptic, without, among, hbp, microorganism, dakota, myrrh,
# Nearest to were: are, was, have, be, had, became, been, semiconducting,
# Nearest to i: we, ii, you, chrysostom, g, megawatts, hodder, koestler,
# Nearest to so: thus, sometimes, impinging, nashe, lucan, conquistadores, lapse, ewald,
# Nearest to use: way, uncommon, form, attributes, dreamt, cause, rethinking, cases,
# Nearest to a: the, another, any, primers, diamagnetism, imperfective, guignol, this,
# Nearest to between: among, with, within, in, whisper, through, etzel, unknowns,
# Nearest to one: two, six, seven, four, eight, five, three, cor,
# Nearest to will: would, may, can, could, must, should, might, shall,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Average loss at step 72000: 3.372384
# Average loss at step 74000: 3.351088
# Average loss at step 76000: 3.312379
# Average loss at step 78000: 3.351237
# Average loss at step 80000: 3.382293
# Nearest to people: men, jews, women, members, students, americans, children, individuals,
# Nearest to in: during, on, within, throughout, until, at, between, through,
# Nearest to b: d, c, f, r, y, afrique, stretching, biochemical,
# Nearest to if: when, though, where, before, does, although, then, because,
# Nearest to at: on, in, during, scrupulously, tk, eq, psychometric, conveniently,
# Nearest to this: which, it, itself, nominating, another, vigilant, some, the,
# Nearest to with: between, skeptic, microorganism, worldly, thermodynamic, through, when, leaving,
# Nearest to were: are, had, was, have, those, became, been, be,
# Nearest to i: ii, chrysostom, you, we, g, t, iii, hodder,
# Nearest to so: thus, impinging, very, indeed, sometimes, ewald, lucan, bottle,
# Nearest to use: form, way, invitation, rethinking, cause, because, dreamt, attributes,
# Nearest to a: another, the, infamously, every, diamagnetism, astoria, primo, bulgakov,
# Nearest to between: among, within, in, with, over, unknowns, through, hegelians,
# Nearest to one: seven, two, six, five, three, eight, four, christiern,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Average loss at step 82000: 3.411976
# Average loss at step 84000: 3.412732
# Average loss at step 86000: 3.387005
# Average loss at step 88000: 3.355464
# Average loss at step 90000: 3.362003
# Nearest to people: men, jews, members, individuals, women, americans, students, children,
# Nearest to in: during, under, within, throughout, between, of, since, until,
# Nearest to b: d, f, r, y, c, h, kbe, winged,
# Nearest to if: when, though, where, before, since, although, does, after,
# Nearest to at: under, during, near, on, scrupulously, within, sculpted, in,
# Nearest to this: it, which, the, some, nolo, itself, vigilant, another,
# Nearest to with: between, hbp, using, worldly, skeptic, through, by, when,
# Nearest to were: are, had, was, while, have, those, although, being,
# Nearest to i: we, g, chrysostom, you, ii, t, iv, mus,
# Nearest to so: thus, too, conquistadores, argue, ewald, grape, impinging, lucan,
# Nearest to use: way, because, rethinking, uncommon, support, study, encoders, needs,
# Nearest to a: another, any, the, every, disobedience, viceroys, imperfective, diamagnetism,
# Nearest to between: with, among, within, through, in, against, shoots, around,
# Nearest to one: seven, eight, two, five, four, three, six, nine,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to four: seven, five, eight, three, six, two, nine, zero,
# Average loss at step 92000: 3.398176
# Average loss at step 94000: 3.255503
# Average loss at step 96000: 3.359991
# Average loss at step 98000: 3.243728
# Average loss at step 100000: 3.353137
# Nearest to people: men, americans, jews, children, students, individuals, women, members,
# Nearest to in: during, within, until, throughout, on, from, into, between,
# Nearest to b: d, aggrieved, ero, eucharistic, y, quinn, synchronous, kar,
# Nearest to if: when, though, where, before, since, after, escapades, unless,
# Nearest to at: on, tk, during, gliders, under, zhu, scrupulously, near,
# Nearest to this: it, which, itself, another, vigilant, he, the, heian,
# Nearest to with: between, thermodynamic, when, using, through, skeptic, speedup, microorganism,
# Nearest to were: are, have, had, those, was, these, being, mafiosi,
# Nearest to i: we, you, ii, chrysostom, they, g, t, megawatts,
# Nearest to so: thus, too, then, therefore, ewald, indeed, sometimes, grape,
# Nearest to use: form, rethinking, cause, way, remakes, improvements, most, support,
# Nearest to a: another, any, the, infamously, every, andhra, diamagnetism, bes,
# Nearest to between: among, through, with, within, shoots, around, against, unknowns,
# Nearest to one: two, four, seven, five, six, eight, th, nine,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,

# %%
# Print final embeddings

print(final_embeddings[0])
# Out:
# [-0.13262393 -0.03070982 -0.02522307  0.00761566  0.03449202  0.03249855
#   0.14641744 -0.08283465  0.08769853  0.18141718 -0.01233952 -0.21104074
#  -0.03945088  0.01579667  0.02093965  0.00964167 -0.12459638 -0.0044656
#  -0.02523237  0.01506175 -0.03114278 -0.05604868 -0.00717896 -0.0237867
#  -0.09282208 -0.0155737   0.08963619  0.073185   -0.12487065  0.06791075
#   0.05674489  0.07325785  0.01848937  0.16404824 -0.01963712 -0.0923856
#  -0.04463993 -0.09214651  0.08063404 -0.04360327 -0.01290093  0.01951326
#  -0.05841969  0.04143432  0.0780443  -0.06014153  0.02562474 -0.09030712
#   0.05963881  0.08592675 -0.11219647  0.05554748 -0.09778026  0.13343339
#   0.06115542  0.01770055  0.13750336 -0.11434589  0.04384092  0.00103688
#  -0.06875936 -0.00365186 -0.07653805 -0.05170685 -0.07074772  0.05596739
#   0.19928497 -0.09516064 -0.12934038  0.01915455  0.17148121  0.01667867
#   0.03782209  0.07594211 -0.06547764 -0.14508587 -0.07975739 -0.24469294
#   0.09954165  0.12625366  0.10933606  0.17611635 -0.00514567  0.02184126
#   0.01164838 -0.0647907  -0.13643377 -0.00715467  0.08362938  0.02733673
#  -0.0802981  -0.05729296  0.00199608  0.01353318  0.16006444  0.16986606
#  -0.16370992  0.08430329  0.03216373  0.13088527 -0.01479035  0.06712703
#  -0.1544085   0.02745628 -0.05918681  0.15704533 -0.02369601  0.14002433
#  -0.06470426  0.09708653 -0.03640939  0.06057712 -0.0445105  -0.05527966
#   0.1342309   0.04824102  0.01049955 -0.05784154  0.10005438 -0.0414843
#  -0.02881577 -0.0363364  -0.04112577 -0.10564211 -0.02088618 -0.05743315
#   0.1001441   0.14616808]

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# For CBOW, need to write a different generate_batch.  Batch shapeos [BATCH_SIZE, SPAN_WINDOW]

# %%
from itertools import compress

def generate_batch_cbow(batch_size, num_skips, skip_window):
    """ Generates a mini batch for CBOW model
    batch_size:  size of mini batch (num of words in mini batch)
    num_skips:   number of surrounding words on both direction (2: one word ahead and one word following)
    skip_windows: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
    
    """
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window 
    
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [skip_window target skip_window]
    buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
    
    # collect the first window of words
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # move the sliding window
    for k in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0
        batch[k, :] = list(compress(buffer, mask))  # all surrounding words
        labels[k, 0] = buffer[skip_window]  # word at the center
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Now construct the TF graph

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1   # How many words at both ends of sentence to skip (1: skip first and last)
num_skips = 2     # Num of surrounding words to left and right (2: one before and one following )

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])  # NOTE CBOW SHAPE CHANGE 
  train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs. Note change for CBOW
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])

  #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, 
                               softmax_biases, 
                               embed,
                               train_labels, 
                               num_sampled, 
                               vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, 
                                            valid_dataset)
  similarity = tf.matmul(valid_embeddings, 
                         tf.transpose(normalized_embeddings))

# %%
# Train the model 

num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, 
                                              num_skips, 
                                              skip_window)
    feed_dict = {train_dataset : batch_data, 
                 train_labels : batch_labels}
    # run one optimizer step
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8    # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.861372
# Nearest to during: ip, tiamat, dominatrices, advantages, genocidal, discoveries, posner, inappropriately,
# Nearest to used: cuts, hyena, circassians, savant, inspiring, commonest, satirizes, recoil,
# Nearest to they: coffey, teeming, procreation, nader, agamemnon, ripping, keys, junkers,
# Nearest to this: embarrassed, wolfram, kornilov, unbeaten, sectarianism, soe, handler, nul,
# Nearest to people: crescent, un, earliest, creditor, angora, detached, shimbun, samarkand,
# Nearest to which: beecher, disciples, precluded, kwan, bernie, tertiary, neoclassicism, emerald,
# Nearest to a: factors, buttocks, wary, conakry, czarist, taping, photoshop, encoding,
# Nearest to known: bitchx, foonly, virginity, contrast, aggressively, tyrone, oppositions, abridgment,
# Nearest to or: zealots, gout, fdi, overpopulation, tempering, oed, angles, moderne,
# Nearest to there: macy, nazarbayev, bas, equipped, te, bums, hartford, comparative,
# Nearest to d: voip, crowning, flightless, krause, hira, backtracking, samir, grattan,
# Nearest to american: microchips, knows, bung, disability, technicolor, dining, publication, swabia,
# Nearest to be: enlists, prostitute, cares, servant, cambodian, patel, lusitania, cooler,
# Nearest to however: collectivization, celibate, avid, calculator, kinds, emil, philosophy, solicit,
# Nearest to by: mekong, vegans, intimidating, swaziland, diva, paleontological, tricyclic, numa,
# Nearest to system: gems, dimaggio, horribly, bmc, categorical, arrests, multiprogramming, regolith,
# Average loss at step 2000: 4.100286
# Average loss at step 4000: 3.563236
# Average loss at step 6000: 3.392712
# Average loss at step 8000: 3.250806
# Average loss at step 10000: 3.174400
# Nearest to during: in, ip, manatus, alignment, memes, inappropriately, necromancer, jade,
# Nearest to used: referred, held, considered, known, yun, kgf, recoil, iulius,
# Nearest to they: he, we, there, catechism, she, you, it, who,
# Nearest to this: it, which, the, qed, its, his, wolfram, chances,
# Nearest to people: earliest, un, reichswehr, already, literally, workbench, alomari, detached,
# Nearest to which: that, this, it, who, also, weekends, what, bridget,
# Nearest to a: the, downside, priestley, troupe, photoshop, dormancy, no, every,
# Nearest to known: well, such, acknowledgment, capcom, used, virginity, mostly, available,
# Nearest to or: and, than, zohar, willy, overpopulation, nazi, divine, goldstein,
# Nearest to there: it, they, vel, he, montezuma, delighted, salvador, clare,
# Nearest to d: b, deutschlands, carpetbaggers, quenched, vsl, krause, slapping, balmoral,
# Nearest to american: english, russian, denominator, racket, swabia, embroidery, masoretic, adv,
# Nearest to be: have, refer, been, lusitania, davros, skinned, madhya, minimise,
# Nearest to however: but, latina, convert, chthonic, presumably, varuna, payload, team,
# Nearest to by: recollections, drew, crawl, matriarch, ewen, for, repeating, eugene,
# Nearest to system: fullerene, horribly, dimaggio, feet, wcl, tigray, endures, unemployment,
# Average loss at step 12000: 3.202543
# Average loss at step 14000: 3.157126
# Average loss at step 16000: 3.177961
# Average loss at step 18000: 3.129381
# Average loss at step 20000: 2.994906
# Nearest to during: in, jade, after, bootstrapping, under, on, within, pindar,
# Nearest to used: known, referred, found, considered, available, held, regarded, yun,
# Nearest to they: we, he, there, you, she, catechism, heraclius, it,
# Nearest to this: which, it, that, the, azteca, underwater, civilisation, minh,
# Nearest to people: others, crescent, literally, brahe, men, alomari, earliest, sqrt,
# Nearest to which: that, this, who, also, these, usually, lignite, what,
# Nearest to a: the, any, blatant, troupe, linguistically, no, photoshop, buttocks,
# Nearest to known: used, such, well, available, foonly, defined, capcom, called,
# Nearest to or: and, than, recommends, paternity, highway, soared, battering, a,
# Nearest to there: they, it, he, said, often, which, montezuma, staking,
# Nearest to d: b, quenched, peabody, deutschlands, vsl, balmoral, carpetbaggers, seraphim,
# Nearest to american: english, amedeo, german, denominator, russian, european, mogul, wafer,
# Nearest to be: been, have, refer, is, lusitania, was, become, bored,
# Nearest to however: but, latina, that, footnote, aristocratic, journeyed, centered, while,
# Nearest to by: from, rationalized, wildcats, matriarch, unchallenged, instantaneous, reordering, lingerie,
# Nearest to system: fullerene, systems, dissident, endures, macquarie, erroneous, mastermind, tigray,
# Average loss at step 22000: 3.080143
# Average loss at step 24000: 3.041081
# Average loss at step 26000: 2.998751
# Average loss at step 28000: 3.029689
# Average loss at step 30000: 3.003273
# Nearest to during: in, after, within, before, under, among, when, jade,
# Nearest to used: known, referred, considered, found, available, regarded, responsible, held,
# Nearest to they: we, there, he, you, she, catechism, it, wallenberg,
# Nearest to this: which, it, that, the, what, civilisation, chances, delight,
# Nearest to people: men, others, days, alomari, jews, countries, brahe, inflectional,
# Nearest to which: that, this, who, however, also, what, it, sporadically,
# Nearest to a: the, photoshop, any, copyrighted, mohair, quaid, troupe, mondegreen,
# Nearest to known: used, such, defined, called, well, regarded, available, filings,
# Nearest to or: and, than, paternity, gemological, bedtime, entanglements, recommends, nada,
# Nearest to there: they, it, he, she, often, these, now, sometimes,
# Nearest to d: b, peabody, balmoral, carpetbaggers, quenched, cis, goren, mathbf,
# Nearest to american: german, british, russian, international, european, denominator, canadian, irish,
# Nearest to be: being, been, refer, was, become, wards, minimise, is,
# Nearest to however: but, although, though, that, journeyed, which, while, when,
# Nearest to by: was, matriarch, through, psychoanalysis, using, intrinsic, surround, lingerie,
# Nearest to system: systems, fullerene, purge, maryland, snail, program, characteristic, burglary,
# Average loss at step 32000: 2.829463
# Average loss at step 34000: 2.954321
# Average loss at step 36000: 2.945128
# Average loss at step 38000: 2.942845
# Average loss at step 40000: 2.927923
# Nearest to during: after, in, when, before, from, through, among, within,
# Nearest to used: known, referred, seen, found, considered, given, described, regarded,
# Nearest to they: we, you, he, there, she, catechism, who, it,
# Nearest to this: it, which, what, chances, civilisation, expedient, azteca, another,
# Nearest to people: men, children, others, jews, those, scientists, alomari, countries,
# Nearest to which: that, this, also, what, who, typically, usually, based,
# Nearest to a: the, dormancy, another, any, blatant, troupe, indicted, firsthand,
# Nearest to known: used, defined, such, called, regarded, available, opposed, foonly,
# Nearest to or: and, deleting, abd, while, rub, vs, deirdre, fredric,
# Nearest to there: they, it, he, she, sometimes, still, said, wallenberg,
# Nearest to d: b, peabody, cis, systematics, quenched, koto, correspondence, karakoram,
# Nearest to american: british, german, canadian, irish, mogul, russian, international, wafer,
# Nearest to be: refer, been, have, become, being, is, was, hinterlands,
# Nearest to however: though, although, but, that, when, while, journeyed, hosted,
# Nearest to by: lafcadio, when, agates, using, from, pileser, during, through,
# Nearest to system: systems, program, process, prague, purge, kazakhs, mined, nast,
# Average loss at step 42000: 2.952512
# Average loss at step 44000: 2.958331
# Average loss at step 46000: 2.915171
# Average loss at step 48000: 2.871993
# Average loss at step 50000: 2.847979
# Nearest to during: after, in, within, before, when, while, although, despite,
# Nearest to used: known, seen, referred, found, considered, described, given, written,
# Nearest to they: we, there, you, he, she, it, catechism, these,
# Nearest to this: which, it, what, expedient, lie, aldehyde, virility, that,
# Nearest to people: men, children, jews, others, women, those, students, millar,
# Nearest to which: that, this, what, usually, also, based, it, however,
# Nearest to a: the, any, photoshop, mohair, troupe, blatant, another, buttocks,
# Nearest to known: used, available, such, regarded, defined, called, possible, opposed,
# Nearest to or: and, than, hydride, proclamations, but, mumia, soared, lowry,
# Nearest to there: they, it, he, we, she, often, usually, wallenberg,
# Nearest to d: b, peabody, karakoram, evokes, catalyzes, j, introducing, quenched,
# Nearest to american: british, german, french, canadian, russian, biotite, denominator, segmentation,
# Nearest to be: been, have, is, being, are, refer, become, lusitania,
# Nearest to however: although, though, but, especially, while, that, where, occur,
# Nearest to by: through, using, when, landline, without, under, crawl, ewen,
# Nearest to system: systems, process, program, prague, calculation, membrane, kazakhs, advisory,
# Average loss at step 52000: 2.890305
# Average loss at step 54000: 2.863148
# Average loss at step 56000: 2.856083
# Average loss at step 58000: 2.755705
# Average loss at step 60000: 2.829741
# Nearest to during: in, within, after, when, at, before, among, through,
# Nearest to used: seen, referred, known, considered, found, described, given, available,
# Nearest to they: we, he, you, there, she, it, i, catechism,
# Nearest to this: which, it, the, dictated, aldehyde, what, azteca, expedient,
# Nearest to people: men, children, women, man, jews, others, scientists, citizens,
# Nearest to which: that, what, this, also, it, usually, who, but,
# Nearest to a: the, another, photoshop, esteemed, troupe, mondegreen, indicted, dormancy,
# Nearest to known: used, defined, such, regarded, called, opposed, available, possible,
# Nearest to or: and, than, but, taklamakan, vs, though, deflation, exclusivity,
# Nearest to there: they, it, she, he, we, still, often, generally,
# Nearest to d: b, quenched, j, peabody, publique, evokes, n, karakoram,
# Nearest to american: british, canadian, irish, australian, german, italian, indian, biotite,
# Nearest to be: been, become, refer, have, being, reach, recover, get,
# Nearest to however: but, although, though, while, especially, that, when, competences,
# Nearest to by: from, through, matriarch, using, under, recollections, ewen, swede,
# Nearest to system: systems, process, membrane, prague, calculation, program, entity, fullerene,
# Average loss at step 62000: 2.831243
# Average loss at step 64000: 2.771521
# Average loss at step 66000: 2.761884
# Average loss at step 68000: 2.718350
# Average loss at step 70000: 2.784882
# Nearest to during: after, in, within, under, when, before, despite, while,
# Nearest to used: referred, seen, employed, described, known, found, allowed, needed,
# Nearest to they: we, you, he, she, there, catechism, it, heraclius,
# Nearest to this: which, it, the, aldehyde, some, apocr, what, dictated,
# Nearest to people: men, children, women, jews, citizens, man, countries, others,
# Nearest to which: that, this, what, also, usually, who, typically, sennacherib,
# Nearest to a: the, another, photoshop, any, altitudes, indicted, fyodor, blatant,
# Nearest to known: such, used, possible, regarded, defined, available, opposed, described,
# Nearest to or: and, stockholm, than, senescence, rub, vs, garb, goldstein,
# Nearest to there: they, it, she, he, we, still, sometimes, often,
# Nearest to d: b, peabody, quenched, evokes, thant, sylvia, kool, byron,
# Nearest to american: british, australian, canadian, german, african, biotite, international, italian,
# Nearest to be: been, become, being, have, refer, is, recover, reach,
# Nearest to however: but, although, though, while, especially, during, that, toe,
# Nearest to by: through, using, mandelbrot, matriarch, without, with, ewen, sociologist,
# Nearest to system: systems, process, program, calculation, fullerene, mined, grosso, constitution,
# Average loss at step 72000: 2.796239
# Average loss at step 74000: 2.642590
# Average loss at step 76000: 2.801779
# Average loss at step 78000: 2.822176
# Average loss at step 80000: 2.784715
# Nearest to during: after, in, within, before, when, despite, throughout, under,
# Nearest to used: seen, known, described, referred, found, employed, allowed, available,
# Nearest to they: we, you, he, there, she, i, it, these,
# Nearest to this: which, it, that, corran, dictated, what, underwater, farragut,
# Nearest to people: men, children, women, man, citizens, jews, persons, others,
# Nearest to which: that, what, this, typically, but, who, these, often,
# Nearest to a: another, hillbillies, the, dormancy, pony, indicted, firsthand, photoshop,
# Nearest to known: used, regarded, possible, available, defined, seen, such, described,
# Nearest to or: and, though, than, fdi, lamenting, gemological, rub, garb,
# Nearest to there: they, it, he, she, we, wallenberg, sometimes, these,
# Nearest to d: b, koto, c, cisc, cis, cdots, ad, might,
# Nearest to american: british, australian, canadian, italian, african, german, irish, indian,
# Nearest to be: become, refer, been, being, have, remain, get, wards,
# Nearest to however: but, although, though, especially, while, that, since, when,
# Nearest to by: using, during, wildcats, mandelbrot, without, through, agates, surround,
# Nearest to system: systems, process, calculation, program, format, fullerene, library, membrane,
# Average loss at step 82000: 2.660169
# Average loss at step 84000: 2.769729
# Average loss at step 86000: 2.731275
# Average loss at step 88000: 2.753490
# Average loss at step 90000: 2.736684
# Nearest to during: in, after, within, before, under, throughout, until, despite,
# Nearest to used: referred, described, seen, known, found, employed, applied, available,
# Nearest to they: we, you, he, there, she, i, it, catechism,
# Nearest to this: which, it, some, what, the, that, illyricum, aldehyde,
# Nearest to people: men, women, children, jews, citizens, students, players, man,
# Nearest to which: that, this, what, typically, also, who, based, often,
# Nearest to a: another, esteemed, any, indicted, fetishism, dormancy, enough, the,
# Nearest to known: regarded, used, possible, described, intended, called, defined, available,
# Nearest to or: and, though, than, garb, nor, griffon, deems, hydride,
# Nearest to there: they, it, she, he, we, sometimes, still, wallenberg,
# Nearest to d: b, c, n, cis, publique, cdots, j, balmoral,
# Nearest to american: australian, british, canadian, african, italian, indian, asian, french,
# Nearest to be: become, have, been, being, refer, get, remain, recover,
# Nearest to however: but, although, though, while, occur, since, especially, occurs,
# Nearest to by: through, without, wildcats, using, mandelbrot, via, agates, surround,
# Nearest to system: systems, process, calculation, program, membrane, maryland, podium, advertisement,
# Average loss at step 92000: 2.675672
# Average loss at step 94000: 2.728114
# Average loss at step 96000: 2.706500
# Average loss at step 98000: 2.366147
# Average loss at step 100000: 2.401488
# Nearest to during: in, after, despite, at, under, before, within, throughout,
# Nearest to used: referred, applied, employed, known, described, seen, required, found,
# Nearest to they: we, he, you, there, she, i, catechism, heraclius,
# Nearest to this: which, it, aldehyde, azteca, his, another, the, some,
# Nearest to people: men, women, children, jews, man, citizens, individuals, person,
# Nearest to which: that, what, this, also, who, typically, often, instead,
# Nearest to a: another, the, fyodor, photoshop, dormancy, lafcadio, altitudes, indicted,
# Nearest to known: regarded, used, available, possible, described, opposed, intended, recognized,
# Nearest to or: and, than, nor, vs, cerevisiae, garb, deflation, but,
# Nearest to there: they, he, it, she, we, still, sometimes, generally,
# Nearest to d: b, monde, peabody, sylvia, deviating, deutschlands, rei, evokes,
# Nearest to american: british, australian, canadian, english, italian, german, irish, idm,
# Nearest to be: become, been, have, being, were, remain, refer, get,
# Nearest to however: but, although, though, that, while, when, since, spends,
# Nearest to by: mandelbrot, through, without, when, from, with, swede, matriarch,
# Nearest to system: systems, process, calculation, allocation, program, plan, network, library,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# CBOW works just as well... it is a bit more compact.
